# %% [markdown]
# Project Euler 16
# ===
#
# $2^{15}=32768$ and the sum of its digits is 3 + 2 + 7 + 6 + 8 = 26.
#
# What is the sum of the digits of the number $2^{1000}$?

# %%
import numpy as np
# %matplotlib inline
import matplotlib.gridspec as gridspec

# %%
A=2**1000
A=str(A)
B=[int(i) for i in A]
print sum(B)
# Out:
# 1366

# %% [markdown]
# 1)
# ---

# %%
#%loadpy http://matplotlib.org/mpl_examples/images_contours_and_fields/streamplot_demo_features.py

# %%
"""
Demo of the `streamplot` function.

A streamplot, or streamline plot, is used to display 2D vector fields. This
example shows a few features of the stream plot function:

    * Varying the color along a streamline.
    * Varying the density of streamlines.
    * Varying the line width along a stream line.
"""
import numpy as np
import matplotlib.pyplot as plt

Y, X = np.mgrid[-3:3:100j, -3:3:100j]
U = -1 - X**2 + Y
V = 1 + X - Y**2
speed = np.sqrt(U*U + V*V)

plt.streamplot(X, Y, U, V, color=U, linewidth=2, cmap=plt.cm.autumn)
plt.colorbar()

f, (ax1, ax2) = plt.subplots(ncols=2)
ax1.streamplot(X, Y, U, V, density=[0.5, 1])

lw = 5*speed/speed.max()
ax2.streamplot(X, Y, U, V, density=0.6, color='k', linewidth=lw)

plt.show()

# %%
#help changing above code
#|
#|
#v

# %%
# generate some data
x = np.arange(0, 10, 0.2)
y = np.sin(x)

# plot it
fig = plt.figure(figsize=(10, 5)) 
gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1]) 
ax0 = plt.subplot(gs[0])
ax0.plot(x, y)
ax1 = plt.subplot(gs[1])
ax1.plot(y, x)

# %% [markdown]
# 2)
# ---

# %%
x,y=zip(*np.genfromtxt('import_files/sunspots.txt'))

plt.figure(figsize=(11,5))
plt.scatter(x,y,marker='.',c=y,cmap=cm.winter_r,lw=0)

axis = plt.gca()

# determining xtick locations and labels
xpos=[i for i in x if i%(25*12)==0]
labels=['{0}'.format(int(1750+i/12)) for i in xpos]

plt.xticks(xpos)
axis.set_xticklabels(labels)

plt.xlim(min(x),max(x))
plt.ylim(0,270)
plt.colorbar()
plt.show()

# %%
x,y=zip(*np.genfromtxt('import_files/sunspots.txt'))

plt.figure(figsize=(11,5))

plt.scatter(x,y,marker='.',c=y,cmap=plt.cm.winter_r,lw=0)
y=[np.average(y[0] if i==0 else y[int(i-24):int(i)]) for i in x]
plt.plot(x,y,color='r',label='running average')

axis = plt.gca()
xpos=[i for i in x[::-1] if i%(25*12)==0]
labels=['{0}'.format(int(1750+i/12)) for i in xpos]
plt.xticks(xpos)
a=axis.set_xticklabels(labels)
plt.xlim(min(x),max(x))
plt.ylim(0,max(y)*1.5)
plt.colorbar()
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# 4)
# ---

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.pyplot as plt

k=8.98e9
fig = plt.figure(figsize=(15,10))
ax = fig.gca(projection='3d') #gca stands for get current axis. the reason being that gca
X = np.linspace(-2.3,2.3,100)
Y = np.linspace(-2.3,2.3,100)
X, Y = np.meshgrid(X, Y)

def R(x,y,locx,locy):
    return np.sqrt((x-locx)**2+(y-locy)**2)
Z=-k/R(X,Y,1,0)-k/R(X,Y,-1,0)+k/R(X,Y,0,1)+k/R(X,Y,0,-1)

surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.seismic, linewidth=0.07, shade=True)

fig.colorbar(surf, shrink=0.5)

plt.show()

# %%
def read_file(f_name):
    try:
        f=open(f_name)
        dat=f.readline()
    except IOError as err:
        print err
        print 'file does not exist:',err.filename
    else:
        f.close()
        return dat

# %%
read_file('import_files/sunspots.txt')
# Out:
# '0\t58.0\n'
